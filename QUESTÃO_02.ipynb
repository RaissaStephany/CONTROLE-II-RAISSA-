# %% [markdown]
# 2 - Para o sistema abaixo, determine o diagrama na forma de controlador e as equações de estados na forma matricial na forma de controlador.

# %%
import numpy as np
import scipy.signal as sig
import sympy as sp
import control as ct
from escrever import *
from IPython.display import display, Math
esc = escrever()

import sympy as sp
z = np.random.randint(low=1,high=10,size=2)
p = np.random.randint(-10,10,3)
s = sp.symbols('s')
L1 = [(s-l) for l in p]
L2 = [(s+l/10) for l in z]
num = np.random.randint(1,20)*sp.prod(L2)
den = sp.prod(L1)
G = num/den
display(Math('G(s) = ' + sp.latex(G)))
# Out:
# $\displaystyle G(s) = \frac{14 \left(s + 0.1\right) \left(s + 0.4\right)}{s \left(s - 7\right) \left(s - 5\right)}$

# %% [markdown]
# $$
# \begin{align*}
# G(s) &= \frac{14(s+0.1)(s+0.4)}{s(s-7)(s-5)}\\
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# G(s) = \frac{14s^2+7s+35}{s^3-12s^2+35s}
# \end{align*}
# $$

# %%
from IPython.display import Image
Image('Diagram_B1.png')

# %% [markdown]
# $$
# \begin{align*}
# \\ \mathbf{\dot{x}} &= \begin{bmatrix}
#     12 & -35 & 0 \\ 1 & 0 & 0 \\ 0 & 1 & 0
# \end{bmatrix} \mathbf{x} +
# \begin{bmatrix}
#     1 \\ 0 \\ 0
# \end{bmatrix} \mathbf{u}\\
#
# \mathbf{y} &= \begin{bmatrix}
#     14 & 7 & 0.56
# \end{bmatrix} \mathbf{x}
#
# \end{align*}
# $$

# %%
#Declarando o sistema:

A = np.matrix([[12,-35,0],[1,0,0],[0,1,0]])
B = np.matrix([[1],[0],[0]])
C = np.matrix([[14, 7, 0.56]])
D = np.matrix([[0]])

sistema = ct.ss(A,B,C,D)
esc.sist(A,B,C,D)
# Out:
# $\displaystyle \dot{\mathbf{x}} = \left[\begin{array}{rrr}12&-35&0\\1&0&0\\0&1&0\\\end{array}\right]\mathbf{x}+\left[\begin{array}{r}1\\0\\0\\\end{array}\right]\mathbf{u}$
# $\displaystyle \mathbf{y} = \left[\begin{array}{rrr}14.0&7.0&0.56\\\end{array}\right]\mathbf{x} + \left[\begin{array}{r}0\\\end{array}\right]\mathbf{u}$
